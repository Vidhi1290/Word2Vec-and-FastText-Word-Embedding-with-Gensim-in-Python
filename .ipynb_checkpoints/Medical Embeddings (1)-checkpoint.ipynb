# %% [markdown]
# # Medical Embeddings and clinical trial search engine

# %%
#  Importing Libraries

# %%
import streamlit as st  #importing streamlit liabrary

# %%
import pandas as pd

import numpy as np
import gensim
from gensim.models import Word2Vec
from gensim.models import FastText
from sklearn.decomposition import PCA
from matplotlib import pyplot

# %%
import matplotlib.pyplot as plt # our main display package
import plotly.graph_objects as go
import string # used for preprocessing
import re # used for preprocessing
import nltk # the Natural Language Toolkit, used for preprocessing
import numpy as np # used for managing NaNs
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords # used for preprocessing
from nltk.stem import WordNetLemmatizer # used for preprocessing
from sklearn.model_selection import train_test_split
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\adarsha.shivananda\AppData\Roaming\nltk_data.
# [nltk_data]     ..
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\adarsha.shivananda\AppData\Roaming\nltk_data.
# [nltk_data]     ..
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\adarsha.shivananda\AppData\Roaming\nltk_data.
# [nltk_data]     ..
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Importing datasets

# %%
df=pd.read_csv('Dimension-covid.csv')   #for preprocessing
df1=pd.read_csv('Dimension-covid.csv')  #for returning results

# %% [markdown]
# # Preprocessing data

# %%
# function to remove all urls
def remove_urls(text):    
    new_text = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text).split())
    return new_text

# make all text lowercase
def text_lowercase(text):
    return text.lower()

# remove numbers
def remove_numbers(text):
    result = re.sub(r'\d+', '', text)
    return result

# remove punctuation
def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)

# tokenize
def tokenize(text):
    text = word_tokenize(text)
    return text

# remove stopwords
stop_words = set(stopwords.words('english'))
def remove_stopwords(text):
    text = [i for i in text if not i in stop_words]
    return text

# lemmatize Words 
lemmatizer = WordNetLemmatizer()
def lemmatize(text):
    text = [lemmatizer.lemmatize(token) for token in text]
    return text

#Creating one function so that all functions can be applied at once
def preprocessing(text):
    
    text = text_lowercase(text)
    text = remove_urls(text)
    text = remove_numbers(text)
    text = remove_punctuation(text)
    text = tokenize(text)
    text = remove_stopwords(text)
    text = lemmatize(text)
    text = ' '.join(text)
    return text

# %%
#Applying preprocessing and removing '\n' character

for i in range(df.shape[0]):
    df['Abstract'][i]=preprocessing(str(df['Abstract'][i])) 
for text in df.Abstract:

    text=text.replace('\n',' ')

# %%
#Applying preprocessing and removing '\n' character

for i in range(df.shape[0]):
    df['Title'][i]=preprocessing(str(df['Title'][i])) 
for text in df.Title:

    text=text.replace('\n',' ')

# %%
x=[word_tokenize(word) for word in df.Abstract ]   #Tokenizing data for training purpose

# %% [markdown]
# # Exploratory data Analysis

# %%
from collections import Counter
cnt = Counter()
for text in df["Abstract"].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(10)  #top 10 common words
# Out:
# [('patient', 38457),
#  ('covid', 38211),
#  ('study', 31963),
#  ('group', 12771),
#  ('treatment', 12471),
#  ('day', 12337),
#  ('sars', 11600),
#  ('cov', 11535),
#  ('clinical', 11507),
#  ('disease', 11395)]

# %%
#Final word cloud after all the cleaning and pre-processing
from wordcloud import WordCloud
from textwrap import wrap
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
#comment_words = ' '
stopwords = set(STOPWORDS) 

# iterate through the csv file 


comment_words=flatten(x)
comment_words=' '.join(comment_words)


wordcloud = WordCloud(width = 800, height = 800, 
            background_color ='white', 
            stopwords = stopwords, 
            min_font_size = 10).generate(comment_words) 

# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 

plt.show()

# %% [markdown]
# # Training skipgram model

# %%
#skipgram = Word2Vec(x, vector_size =50, window = 3, min_count=2,sg = 1)
#print(skipgram)
#skipgram.save('skipgramx1.bin')
#skipgram = Word2Vec.load('skipgramx1.bin')

# %%
skipgram = Word2Vec(x, vector_size =100, window = 1, min_count=2,sg = 1)
print(skipgram)
skipgram.save('skipgramx11.bin')

# %%
# Loading the model
skipgram = Word2Vec.load('skipgramx11.bin')

# %% [markdown]
# # Training Fasttext model

# %%
#fast_n= FastText(x,vector_size=200, window=3, min_count=2, workers=5, min_n=1, max_n=2,sg=1)  #training fasttext Model, with skipgram
#fast_n=fast_n.save('fast_p.bin')    #Saving our model
#fast_n = Word2Vec.load('fast_p.bin')  #Loading our pretrained model
# Out:
# 2021-06-13 15:07:13.827 INFO    gensim.models.word2vec: collecting all words and their counts
# 2021-06-13 15:07:13.828 INFO    gensim.models.word2vec: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-06-13 15:07:14.813 INFO    gensim.models.word2vec: PROGRESS: at sentence #10000, processed 2024809 words, keeping 39392 word types
# 2021-06-13 15:07:14.850 INFO    gensim.models.word2vec: collected 39969 word types from a corpus of 2088009 raw words and 10666 sentences
# 2021-06-13 15:07:14.852 INFO    gensim.models.word2vec: Creating a fresh vocabulary
# 2021-06-13 15:07:15.240 INFO    gensim.utils: FastText lifecycle event {'msg': 'effective_min_count=1 retains 39969 unique words (100.0%% of original 39969, drops 0)', 'datetime': '2021-06-13T15:07:15.240715', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2021-06-13 15:07:15.242 INFO    gensim.utils: FastText lifecycle event {'msg': 'effective_min_count=1 leaves 2088009 word corpus (100.0%% of original 2088009, drops 0)', 'datetime': '2021-06-13T15:07:15.242710', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2021-06-13 15:07:15.759 INFO    gensim.models.word2vec: deleting the raw counts dictionary of 39969 items
# 2021-06-13 15:07:15.763 INFO    gensim.models.word2vec: sample=0.001 downsamples 32 most-common words
# 2021-06-13 15:07:15.778 INFO    gensim.utils: FastText lifecycle event {'msg': 'downsampling leaves estimated 1944588.4195863355 word corpus (93.1%% of prior 2088009)', 'datetime': '2021-06-13T15:07:15.778299', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# 2021-06-13 15:07:17.193 INFO    gensim.models.fasttext: estimated required memory for 39969 words, 2000000 buckets and 50 dimensions: 442622868 bytes
# 2021-06-13 15:07:17.195 INFO    gensim.models.word2vec: resetting layer weights
# 2021-06-13 15:07:21.930 INFO    gensim.utils: FastText lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2021-06-13T15:07:21.930827', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'build_vocab'}
# 2021-06-13 15:07:21.931 INFO    gensim.utils: FastText lifecycle event {'msg': 'training model with 5 workers on 39969 vocabulary and 50 features, using sg=1 hs=0 sample=0.001 negative=5 window=1', 'datetime': '2021-06-13T15:07:21.931825', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'train'}
# 2021-06-13 15:07:23.017 INFO    gensim.models.word2vec: EPOCH 1 - PROGRESS: at 15.01% examples, 313258 words/s, in_qsize 9, out_qsize 0
# 2021-06-13 15:07:24.027 INFO    gensim.models.word2vec: EPOCH 1 - PROGRESS: at 33.28% examples, 341533 words/s, in_qsize 10, out_qsize 0
# 2021-06-13 15:07:25.061 INFO    gensim.models.word2vec: EPOCH 1 - PROGRESS: at 51.32% examples, 346866 words/s, in_qsize 10, out_qsize 1
# 2021-06-13 15:07:26.068 INFO    gensim.models.word2vec: EPOCH 1 - PROGRESS: at 69.98% examples, 355560 words/s, in_qsize 9, out_qsize 0
# 2021-06-13 15:07:27.083 INFO    gensim.models.word2vec: EPOCH 1 - PROGRESS: at 88.25% examples, 351884 words/s, in_qsize 9, out_qsize 0
# 2021-06-13 15:07
INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 1 more threads
# 2021-06-13 15:07:48.891 INFO    gensim.models.word2vec: worker thread finished; awaiting finish of 0 more threads
# 2021-06-13 15:07:48.893 INFO    gensim.models.word2vec: EPOCH - 5 : training on 2088009 raw words (1944624 effective words) took 5.0s, 385179 effective words/s
# 2021-06-13 15:07:48.895 INFO    gensim.utils: FastText lifecycle event {'msg': 'training on 10440045 raw words (9722587 effective words) took 27.0s, 360606 effective words/s', 'datetime': '2021-06-13T15:07:48.895734', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'train'}
# 2021-06-13 15:07:50.863 INFO    gensim.utils: FastText lifecycle event {'params': 'FastText(vocab=39969, vector_size=50, alpha=0.025)', 'datetime': '2021-06-13T15:07:50.863472', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'created'}
# 2021-06-13 15:07:50.865 INFO    gensim.utils: FastText lifecycle event {'fname_or_handle': 'fast.bin', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2021-06-13T15:07:50.865469', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'saving'}
# 2021-06-13 15:07:50.867 INFO    gensim.utils: storing np array 'vectors_ngrams' to fast.bin.wv.vectors_ngrams.npy
# 2021-06-13 15:07:56.494 INFO    gensim.utils: not storing attribute vectors
# 2021-06-13 15:07:56.496 INFO    gensim.utils: not storing attribute buckets_word
# 2021-06-13 15:07:56.498 INFO    gensim.utils: not storing attribute cum_table
# 2021-06-13 15:07:56.595 INFO    gensim.utils: saved fast.bin
# 2021-06-13 15:07:56.673 INFO    gensim.utils: loading Word2Vec object from fast.bin
# 2021-06-13 15:07:56.865 INFO    gensim.utils: loading wv recursively from fast.bin.wv.* with mmap=None
# 2021-06-13 15:07:56.866 INFO    gensim.utils: loading vectors_ngrams from fast.bin.wv.vectors_ngrams.npy with mmap=None
# 2021-06-13 15:07:57.189 INFO    gensim.utils: setting ignored attribute vectors to None
# 2021-06-13 15:07:57.191 INFO    gensim.utils: setting ignored attribute buckets_word to None
# 2021-06-13 15:08:00.507 INFO    gensim.utils: setting ignored attribute cum_table to None
# 2021-06-13 15:08:01.273 INFO    gensim.utils: FastText lifecycle event {'fname': 'fast.bin', 'datetime': '2021-06-13T15:08:01.273954', 'gensim': '4.0.1', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'loaded'}

# %%
FastText=FastText(x,vector_size=100, window=2, min_count=2, workers=5, min_n=1, max_n=2,sg=1)
FastText.save('FastText.bin')    #Saving our model
FastText = Word2Vec.load('FastText.bin')  #Loading our pretrained model

# %% [markdown]
# ## Model embeddings - Similarity

# %%
# Similar words

skipgram.wv.most_similar(positive=['corona'],topn=10)
# Out:
# [('coronavirus', 0.7522148489952087),
#  ('covid', 0.7046160697937012),
#  ('evd', 0.6866053938865662),
#  ('novelty', 0.6846073269844055),
#  ('crown', 0.6796512007713318),
#  ('ebola', 0.6733856797218323),
#  ('declares', 0.6625796556472778),
#  ('betacoronavirus', 0.6608704328536987),
#  ('virulent', 0.6600514054298401),
#  ('accidental', 0.6592734456062317)]

# %%
skipgram.wv.most_similar(positive=['patient'],topn=10)
# Out:
# [('hospitalised', 0.7468649744987488),
#  ('subject', 0.7405608892440796),
#  ('participant', 0.7305842638015747),
#  ('acutely', 0.7300373315811157),
#  ('individual', 0.7294930815696716),
#  ('moderately', 0.7198054194450378),
#  ('recovering', 0.7098079323768616),
#  ('survivor', 0.6955605149269104),
#  ('chronically', 0.6909738779067993),
#  ('pwcf', 0.6897059679031372)]

# %%
FastText.wv.most_similar(positive=['lung'],topn=10)
# Out:
# [('lungiq', 0.7296534180641174),
#  ('sung', 0.6896412372589111),
#  ('leung', 0.6812748908996582),
#  ('alveolus', 0.6693559885025024),
#  ('silicovilung', 0.667030394077301),
#  ('pulmonary', 0.6625018119812012),
#  ('flushing', 0.6576013565063477),
#  ('volunteering', 0.6545701622962952),
#  ('halving', 0.6542454957962036),
#  ('solving', 0.6514652967453003)]

# %%
FastText.wv.most_similar(positive=['breathing'],topn=10)
# Out:
# [('rebreathing', 0.9137265086174011),
#  ('breaching', 0.9036466479301453),
#  ('breathe', 0.8783586025238037),
#  ('breathed', 0.8577072024345398),
#  ('bathing', 0.8560777902603149),
#  ('breaking', 0.8555806875228882),
#  ('breath', 0.8513644337654114),
#  ('threatening', 0.8443984985351562),
#  ('heating', 0.8398532271385193),
#  ('sweating', 0.839706301689148)]

# %% [markdown]
# # PCA Plot - Skipgram

# %%
X = skipgram.wv[skipgram.wv.index_to_key]    #stroing arrays of all words
pca = PCA(n_components=2)                    #applying PCA to convert data into two dimensions
result = pca.fit_transform(X)

# %%
#words embeddings on the plot to check 2-D representation of each word
pyplot.scatter(result[:10, 0], result[:10, 1])
words = list(skipgram.wv.index_to_key)
for i, word in enumerate(words[:10]):
    pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()

# %% [markdown]
# # PCA Plot - Fasttest

# %%
#same thing as above but with fasttext model
X_fast = FastText.wv[FastText.wv.index_to_key]
pca = PCA(n_components=2)
result_fast = pca.fit_transform(X_fast)

# %%
pyplot.scatter(result_fast[:10, 0], result_fast[:10, 1])
words = list(FastText.wv.index_to_key)
for i, word in enumerate(words[:10]):
    pyplot.annotate(word, xy=(result_fast[i, 0], result_fast[i, 1]))
pyplot.show()

# %% [markdown]
# # Getting Vectors for each abstract

# %%
vector_size=100   #defining vector size for each word

# %% [markdown]
# ### Method 1

# %%
#function to take average of all vectors of each word in abstract, so that each abstract can represent (1,50) dimensional vector

K1=[]      #creating list to store vector representation of each abstract

for i in range(df.shape[0]):       #iterating through all abstract
    K=np.zeros([vector_size,1])    #creating empty array of size (vec_size,1) to add vector representation of each word
    count=0                        #creating count to check how many words are used from abstract
    
    for word in word_tokenize(df['Abstract'][i]):   #iterating through all words in given abstract

        if word in list(fast_n.wv.index_to_key):      #if word exists in vocab , increase count by 1 and add array of given words in our defined array K

            count+=1
            K+=fast_n.wv[word].reshape(vector_size,1)
    K=K/count                                        #taking average of given array
    K1.append(list(K))                               #appending vector of given abstract to the initial defined list
K1_array=np.array(K1)
K1_array=K1_array.reshape(df.shape[0],vector_size)   #converting into array of shape(no. of rows, vector_size)

# %% [markdown]
# ### Method 2

# %%
def get_mean_vector(word2vec_model, words):
    # remove out-of-vocabulary words
    words = [word for word in tokenize(words) if word in list(word2vec_model.wv.index_to_key)] #if word is in vocab 
    if len(words) >= 1:
        return np.mean(word2vec_model.wv[words], axis=0)
    else:
        return np.array([0]*100)

# %% [markdown]
# ### Abstract to vectors using skipgram Model

# %%
K1=[]                                     #defining empty list
for i in df.Abstract:
    K1.append(list(get_mean_vector(skipgram, i)))     #appending array to the list

# %%
#K11=pd.DataFrame(K1).transpose()    # Saving vectors of each abstract in data frame so that we can use directly while running code again
#K11.to_csv('skipgram-vec.csv')

# %%
K=pd.read_csv('skipgram-vec.csv')   #Loading our pretrained vectors of each abstract

K2=[]                          #transforming dataframe into required array like structure as we did in above step
for i in range(df.shape[0]):
    K2.append(K[str(i)].values)

# %% [markdown]
# ### For converting Title into vectors using skipgram

# %%
K1_title=[]
for i in df.Title:         #instead of abstract use title
    K1_title.append(list(get_mean_vector(skipgram, i)))

# %%
K1_title=pd.DataFrame(K1).transpose()    # Saving vectors of each abstract in data frame so that we can use directly while running code again
K1_title.to_csv('skipgram-vec-title.csv')

# %%
K=pd.read_csv('skipgram-vec-title.csv')   #Loading our pretrained vectors of each abstract

K2_title=[]                          #transforming dataframe into required array like structure as we did in above step
for i in range(df.shape[0]):
    K2_title.append(K[str(i)].values)

# %% [markdown]
# ### Abstract to vector using FastText

# %%
K_fast=[]                                     #defining empty list
for i in df.Abstract:
    K_fast.append(list(get_mean_vector(FastText, i)))     #appending array to the list

# %%
K11=pd.DataFrame(K_fast).transpose()    # Saving vectors of each abstract in data frame so that we can use directly while running code again
K11.to_csv('FastText-vec.csv')

# %%
data=pd.read_csv('FastText-vec.csv')   #Loading our pretrained vectors of each abstract

K_fast=[]                          #transforming dataframe into required array like structure as we did in above step
for i in range(df.shape[0]):
    K_fast.append(data[str(i)].values)

# %% [markdown]
# # cosine similarity function

# %%
#defining function to define cosine similarity
from numpy import dot
from numpy.linalg import norm
def cos_sim(a,b):

    return dot(a, b)/(norm(a)*norm(b))

# %% [markdown]
# # Input query Preprocessing

# %%
#Preprocessing input, because input should be in same form as training data set
def preprocessing_input(query):
    query=preprocessing(query)
    query=query.replace('\n',' ')
    K=get_mean_vector(FastText,query)
   
        
    return K

# %% [markdown]
# # Function to return 'n' similar results

# %%
pd.set_option("display.max_colwidth", -1)       #this function will display full text from each column
# Out:
# <ipython-input-25-a25b7124b1bb>:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option("display.max_colwidth", -1)       #this function will display full text from each column

# %%
#function to return top n similar results
def top_n(query,p,df1):    
    
    query=preprocessing_input(query)    #preprocessing input to list of vectors
                                    
    x=[]
    #Converting cosine similarities of overall data set with input queries into LIST
    for i in range(len(p)):
        x.append(cos_sim(query,p[i]))
    
    
 #store list in tmp to retrieve index
    tmp=list(x)
    
 #sort list so that largest elements are on the far right
    
    res = sorted(range(len(x)), key = lambda sub: x[sub])[-10:]
    sim=[tmp[i] for i in reversed(res)]
    print(sim)
 #get index of the 10 or n largest element
    L=[]
    for i in reversed(res):
    
        L.append(i)
# 1528   multiple myeloma including MGUS chronic lymphocytic leukemia, chronic myeloid leukemia, acute myeloid leukemia, acute lymphocytic leukemia, non-Hodgkin lymphoma, Hodgkin lymphoma, myelodysplastic syndrome, myeloproliferative disease
# 3071   Chronic obstructive pulmonary disease COPD and bronchiectasis
#
#       Publication date
# 1984   2021-01-26
# 548    2021-03-31
# 9945   2020-02-26
# 10414  2020-02-01
# 468    2020-03-20
# 1543   2021-03-24
# 3473   2020-10-23
# 8122   2020-04-16
# 1528   2021-03-10
# 3071   2020-11-27

# %%
top_n("kidney",K2,df1)
# Out:
# [0.8881463307711879, 0.7517814549020215, 0.7451755420127439, 0.7407882134960713, 0.7386895284916424, 0.7364842788423694, 0.7322410969251204, 0.7305951725069977, 0.7211926756347459, 0.7187581989409669]
#                Trial ID                                              Title  \
# 1984     2021-000412-28  COVID-19: Sars-Cov2 vaccination in kidney tran...
# 3473     2020-001467-82  An Open-Label Study Evaluating Anti-Viral Effe...
# 3071     2020-004951-34  Community participants with COPD or bronchiect...
# 10414  CHICTR2000030030  The risk factor and prognosis of acute kidney ...
# 1543     2020-005416-22  A Phase 3 Randomized, Double-Blind, Placebo-Co...
# 548      2021-000988-68  Immune response after covid-19 vaccination in ...
# 468         NCT04872764  The Effect of Acute Kidney Injury on Prognosis...
# 2323        NCT04728906  Targeted-cell Therapy Using Epithelial Stem Ce...
# 9945        NCT04316299  Acute Kidney Injury in Patients Hospitalized W...
# 9141   CHICTR2000032009  Clinical characteristics and risk factors of n...
#
#                                                 Abstract Publication date
# 1984                          Kidney transplant patients       2021-01-26
# 3473   SARS-CoV-2 infection in Kidney Transplant Reci...       2020-10-23
# 3071   Chronic obstructive pulmonary disease COPD and...       2020-11-27
# 10414  To demonstrate the abnormal urine analysis and...       2020-02-01
# 1543   Coronavirus disease 2019 COVID-19 in patients ...       2021-03-24
# 548                         Renal failure stage 4 and 5.       2021-03-31
# 468    We aimed to investigate the effect of Acute Ki...       2020-03-20
# 2323   Myocardial infarction (MI), as one of the many...       2021-03-05
# 9945   The kidney may be affected in coronavirus-2019...       2020-02-26
# 9141   We aim to investigate the intraction between c...       2020-04-17

# %% [markdown]
# # Streamlit App (Refer Medical.py file to run the app)

# %%
#streamlit function 
def main():
    # Load data and models
    data = df1     #our data which we have to display
    model = top_n  #top_n model to return n similar results
    

    st.title("Medical Search engine")      #title of our app
    st.write('Type your query here')       #text below title

    # User search
    user_input = st.text_input("Search box")   #getting input from user

   
    # Fetch results
    if user_input:
        
        P,sim =model(str(user_input),K2,data)     #storing our output dataframe in P
        #Plotly function to display our dataframe in form of plotly table
        fig = go.Figure(data=[go.Table(header=dict(values=['ID', 'Title','Abstract','Publication Date','Similarity']),cells=dict(values=[list(P['Trial ID'].values),list(P['Title'].values), list(P['Abstract'].values),list(P['Publication date'].values),list(np.around(sim,4))],align='center'))])
        #displying our plotly table
        fig.update_layout(height=1700) 
        st.plotly_chart(fig) 
        # Get individual results
    

if __name__ == "__main__":
    main()
# Out:
# 2021-06-12 22:13:33.498 WARNING root:
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\NEERAJ\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
